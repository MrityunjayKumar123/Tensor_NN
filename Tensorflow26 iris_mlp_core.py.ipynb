# %%
# Traing test dataset

# %%
import os
import pandas
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt


os.chdir(r"/Users/mrityunjay/Desktop/Deep Learning/Assignment/")

names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'species']

data_train = pandas.read_csv('iris_training.csv',names=names,skiprows=1)
data_test  = pandas.read_csv('iris_test.csv',names=names,skiprows=1)


# Training & test. data & label

X  = data_train.drop(labels=['species'], axis=1).values
y  = data_train.species.values

X1  = data_test.drop(labels=['species'], axis=1).values
y1  = data_test.species.values

# random seed
seed = 5
np.random.seed(seed)
tf.compat.v1.set_random_seed(seed)

# Creating Index for train & test
train_index = np.random.choice(len(X), round(len(X) * 1), replace=False)
test_index  = np.random.choice(len(X1), round(len(X1) * 1), replace=False)

# train & test 

train_X = X[train_index]
train_y = y[train_index]
test_X = X1[test_index]
test_y = y1[test_index]


model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])


model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_X, train_y, epochs=50)

model.evaluate(test_X, test_y)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0824 22:19:36.189703 4763538880 deprecation.py:323] From /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 120 samples
# Epoch 1/50
# 120/120 [==============================] - 0s 3ms/sample - loss: 1.8258 - accuracy: 0.3917
# Epoch 2/50
# 120/120 [==============================] - 0s 100us/sample - loss: 1.2776 - accuracy: 0.5333
# Epoch 3/50
# 120/120 [==============================] - 0s 131us/sample - loss: 0.9732 - accuracy: 0.7583
# Epoch 4/50
# 120/120 [==============================] - 0s 218us/sample - loss: 0.8119 - accuracy: 0.7333
# Epoch 5/50
# 120/120 [==============================] - 0s 153us/sample - loss: 0.7290 - accuracy: 0.7333
# Epoch 6/50
# 120/120 [==============================] - 0s 177us/sample - loss: 0.6821 - accuracy: 0.7417
# Epoch 7/50
# 120/120 [==============================] - 0s 243us/sample - loss: 0.6228 - accuracy: 0.7917
# Epoch 8/50
# 120/120 [==============================] - 0s 214us/sample - loss: 0.5688 - accuracy: 0.7917
# Epoch 9/50
# 120/120 [==============================] - 0s 162us/sample - loss: 0.5582 - accuracy: 0.7583
# Epoch 10/50
# 120/120 [==============================] - 0s 193us/sample - loss: 0.5297 - accuracy: 0.7500
# Epoch 11/50
# 120/120 [==============================] - 0s 136us/sample - loss: 0.4863 - accuracy: 0.8167
# Epoch 12/50
# 120/120 [==============================] - 0s 240us/sample - loss: 0.4964 - accuracy: 0.8083
# Epoch 13/50
# 120/120 [==============================] - 0s 170us/sample - loss: 0.4773 - accuracy: 0.8333
# Epoch 14/50
# 120/120 [==============================] - 0s 168us/sample - loss: 0.4497 - accuracy: 0.8167
# Epoch 15/50
# 120/120 [==============================] - 0s 135us/sample - loss: 0.4654 - accuracy: 0.8083
# Epoch 16/50
# 120/120 [==============================] - 0s 78us/sample - loss: 0.4315 - accuracy: 0.8167
# Epoch 17/50
# 120/120 [==============================] - 0s 263us/sample - loss: 0.3961 - accuracy: 0.8917
# Epoch 18/50
# 120/120 [==============================] - 0s 253us/sample - loss: 0.4085 - accuracy: 0.8583
# Epoch 19/50
# 120/120 [==============================] - 0s 76us/sample - loss: 0.3873 - accuracy: 0.8833
# Epoch 20/50
# 120/120 [==============================] - 0s 271us/sample - loss: 0.3859 - accuracy: 0.8333
# Epoch 21/50
# 120/120 [==============================] - 0s 206us/sample - loss: 0.3875 - accuracy: 0.8750
# Epoch 22/50
# 120/120 [==============================] - 0s 115us/sample - loss: 0.3616 - accuracy: 0.8833
# Epoch 23/50
# 120/120 [==============================] - 0s 199us/sample - loss: 0.3447 - accuracy: 0.8750
# Epoch 24/50
# 120/120 [==============================] - 0s 85us/sample - loss: 0.3287 - accuracy: 0.9333
# Epoch 25/50
# 120/120 [==============================] - 0s 257us/sample - loss: 0.3443 - accuracy: 0.8917
# Epoch 26/50
# 120/120 [==============================] - 0s 228us/sample - loss: 0.3360 - accuracy: 0.9167
# Epoch 27/50
# 120/120 [==============================] - 0s 125us/sample - loss: 0.3234 - accuracy: 0.9250
# Epoch 28/50
# 120/120 [==============================] - 0s 123us/sample - loss: 0.2977 - accuracy: 0.9500
# Epoch 29/50
# 120/120 [==============================] - 0s 111us/sample - loss: 0.2887 - accuracy: 0.9667
# Epoch 30/50
# 120/120 [==============================] - 0s 117us/sample - loss: 0.3067 - accuracy: 0.9333
# Epoch 31/50
# 120/120 [==============================] - 0s 242us/sample - loss: 0.3007 - accuracy: 0.9000
# Epoch 32/50
# 120/120 [==============================] - 0s 117us/sample - loss: 0.2946 - accuracy: 0.9417
# Epoch 33/50
# 120/120 [==============================] - 0s 124us/sample - loss: 0.2755 - accuracy: 0.9583
# Epoch 34/50
# 120/120 [==============================] - 0s 114us/sample - loss: 0.2682 - accuracy: 0.9583
# Epoch 35/50
# 120/120 [==============================] - 0s 100us/sample - loss: 0.2655 - accuracy: 0.9417
# Epoch 36/50
# 120/120 [==============================] - 0s 277us/sample - loss: 0.2700 - accuracy: 0.9083
# Epoch 37/50
# 120/120 [==============================] - 0s 122us/sample - loss: 0.2606 - accuracy: 0.9250
# Epoch 38/50
# 120/120 [==============================] - 0s 119us/sample - loss: 0.2726 - accuracy: 0.9333
# Epoch 39/50
# 120/120 [==============================] - 0s 881us/sample - loss: 0.2469 - accuracy: 0.9500
# Epoch 40/50
# 120/120 [==============================] - 0s 303us/sample - loss: 0.2347 - accuracy: 0.9500
# Epoch 41/50
# 120/120 [==============================] - 0s 106us/sample - loss: 0.2506 - accuracy: 0.9333
# Epoch 42/50
# 120/120 [==============================] - 0s 202us/sample - loss: 0.2271 - accuracy: 0.9500
# Epoch 43/50
# 120/120 [==============================] - 0s 233us/sample - loss: 0.2315 - accuracy: 0.9583
# Epoch 44/50
# 120/120 [==============================] - 0s 145us/sample - loss: 0.2248 - accuracy: 0.9667
# Epoch 45/50
# 120/120 [==============================] - 0s 112us/sample - loss: 0.2111 - accuracy: 0.9667
# Epoch 46/50
# 120/120 [==============================] - 0s 116us/sample - loss: 0.1859 - accuracy: 0.9917
# Epoch 47/50
# 120/120 [==============================] - 0s 245us/sample - loss: 0.1988 - accuracy: 0.9667
# Epoch 48/50
# 120/120 [==============================] - 0s 221us/sample - loss: 0.1880 - accuracy: 0.9833
# Epoch 49/50
# 120/120 [==============================] - 0s 114us/sample - loss: 0.1998 - accuracy: 0.9583
# Epoch 50/50
# 120/120 [==============================] - 0s 534us/sample - loss: 0.2163 - accuracy: 0.9250
# 30/30 [==============================] - 0s 3ms/sample - loss: 0.2000 - accuracy: 0.9667
# [0.19998934864997864, 0.96666664]
