# %%
# Mrityunjay kumar # 
# TensorFlow 7 (Neural Network - Classification Example + Saver_ to save the Neural Network)

# %%
import matplotlib
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt

#defining the structure of a layer
tf.compat.v1.disable_eager_execution()


def add_layer(inputs,in_size,out_size,activation_function=None):
    #inputs from previous layer
    #in_size: size(number of neurons) of previous layer
    #out_size: size(number of neurons) of this layer
    #activation_function: used in this layer
    Weights = tf.compat.v1.Variable(tf.compat.v1.random_normal([in_size,out_size]),name='W')
    biases = tf.compat.v1.Variable(tf.compat.v1.zeros([1,out_size])+0.1,name='b')
    logit = tf.compat.v1.matmul(inputs,Weights) + biases
    if activation_function is None:
        output = logit
    else:
        output = activation_function(logit,)
    return output

#calculating accuracy
def compute_accuracy(xtest,ytest):
    global predicted
    ypred = sess.run(predicted,feed_dict={xs:xtest})
    correct_pred = tf.compat.v1.equal(tf.compat.v1.arg_max(ypred,1),tf.compat.v1.arg_max(ytest,1))
    accuracy = tf.compat.v1.reduce_mean(tf.compat.v1.cast(correct_pred,tf.compat.v1.float32))
    result = sess.run(accuracy,feed_dict={xs:xtest,ys:ytest})
    return result

import input_data
mnist = input_data.read_data_sets("MNIST/", one_hot=True)

#define placeholders for input to networks
xs = tf.compat.v1.placeholder(tf.compat.v1.float32,[None,784])  #28x28=784
ys = tf.compat.v1.placeholder(tf.compat.v1.float32,[None,10])   # 10 output classes

#just adding one layer i.e. directly the output layer
#adding one layer
predicted = add_layer(xs,784,10,tf.compat.v1.nn.softmax)

#y_hat_softmax = tf.nn.softmax(y_hat)  , yhat is logit
#total_loss = tf.reduce_mean(-tf.reduce_sum(y_true * tf.log(y_hat_softmax), [1]))
#or
#total_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(y_hat, y_true))

cross_entropy = tf.compat.v1.reduce_mean(-tf.compat.v1.reduce_sum(ys*tf.compat.v1.log(predicted),reduction_indices=[1]))
training = tf.compat.v1.train.GradientDescentOptimizer(0.5).minimize(cross_entropy)

sess = tf.compat.v1.Session()

#important step
sess.run(tf.compat.v1.initialize_all_variables())


for i in range(20000):
    batch_xs,batch_ys = mnist.train.next_batch(1000)
    sess.run(training,feed_dict={xs:batch_xs,ys:batch_ys})
    if i%100==0:
        print ( compute_accuracy(mnist.test.images,mnist.test.labels))
# Out:
# Extracting MNIST/train-images-idx3-ubyte.gz
# Extracting MNIST/train-labels-idx1-ubyte.gz
# Extracting MNIST/t10k-images-idx3-ubyte.gz
# Extracting MNIST/t10k-labels-idx1-ubyte.gz
# W0128 15:26:56.028317 4371494336 deprecation.py:323] From /anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:193: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# W0128 15:26:56.336858 4371494336 deprecation.py:323] From <ipython-input-5-6331da7c8dbf>:28: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.math.argmax` instead
# 0.1201
# 0.7466
# 0.8084
# 0.8328
# 0.8472
# 0.8563
# 0.864
# 0.8676
# 0.8716
# 0.8737
# 0.8761
# 0.8795
# 0.8822
# 0.8834
# 0.8864
# 0.8875
# 0.8881
# 0.8914
# 0.8914
# 0.8928
# 0.8928
# 0.8952
# 0.8954
# 0.8974
# 0.8981
# 0.8979
# 0.8992
# 0.899
# 0.9005
# 0.9013
# 0.9017
# 0.9032
# 0.9032
# 0.9036
# 0.9036
# 0.9045
# 0.905
# 0.9052
# 0.9055
# 0.9062
# 0.9061
# 0.9069
# 0.9067
# 0.9073
# 0.9077
# 0.908
# 0.9081
# 0.9088
# 0.9088
# 0.9089
# 0.9081
# 0.9084
# 0.9098
# 0.9098
# 0.9103
# 0.9104
# 0.9096
# 0.9094
# 0.9111
# 0.9106
# 0.9112
# 0.9124
# 0.9119
# 0.9121
# 0.9116
# 0.9127
# 0.9125
# 0.9129
# 0.913
# 0.9127
# 0.9136
# 0.9129
# 0.9141
# 0.9137
# 0.9141
# 0.9136
# 0.9155
# 0.9138
# 0.9146
# 0.914
# 0.916
# 0.9154
# 0.9153
# 0.9161
# 0.9161
# 0.9165
# 0.9151
# 0.9164
# 0.9162
# 0.9157
# 0.9161
# 0.9162
# 0.9177
# 0.9165
# 0.915
# 0.9167
# 0.9159
# 0.9176
# 0.9183
# 0.9178
# 0.919
# 0.918
# 0.9187
# 0.9183
# 0.9182
# 0.9181
# 0.9188
# 0.9197
# 0.9183
# 0.9195
# 0.9196
# 0.919
# 0.9196
# 0.9194
# 0.9194
# 0.9192
# 0.9199
# 0.9197
# 0.9196
# 0.9213
# 0.9197
# 0.92
# 0.9212
# 0.9199
# 0.9207
# 0.92
# 0.9205
# 0.9206
# 0.9208
# 0.9213
# 0.9212
# 0.9213
# 0.9214
# 0.9202
# 0.9209
# 0.9205
# 0.9206
# 0.9208
# 0.92
# 0.9214
# 0.9226
# 0.9208
# 0.9218
# 0.9222
# 0.9226
# 0.9227
# 0.9221
# 0.9223
# 0.9218
# 0.9231
# 0.9239
# 0.9227
# 0.9235
# 0.9217
# 0.9235
# 0.923
# 0.9229
# 0.9226
# 0.9232
# 0.9235
# 0.9234
# 0.9216
# 0.9233
# 0.9218
# 0.9231
# 0.9223
# 0.9236
# 0.9225
# 0.9226
# 0.9232
# 0.9226
# 0.9221
# 0.9227
# 0.9239
# 0.9231
# 0.9215
# 0.923
# 0.9222
# 0.9229
# 0.9238
# 0.9233
# 0.9235
# 0.9242
# 0.9234
# 0.9227
# 0.9216
# 0.9245
# 0.9226
# 0.9244
# 0.9231
# 0.9232
# 0.9235
# 0.9222
# 0.9232
# 0.9237
# 0.922
# 0.9235
# 0.9241
# 0.9237
# 0.9235

# %%
#saver : how to save your neural network
#save to ckpt file type
#remember the dtype, shape and name while restoring

#next cell : saving weights and biases in ckpt file
#next to next cell : restoring the weights and biases

# %%
import matplotlib
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt

#defining the structure of a layer

def add_layer(inputs,in_size,out_size,activation_function=None):
    #inputs from previous layer
    #in_size: size(number of neurons) of previous layer
    #out_size: size(number of neurons) of this layer
    #activation_function: used in this layer
    Weights = tf.compat.v1.Variable(tf.compat.v1.random_normal([in_size,out_size]),dtype=tf.compat.v1.float32,name='W')
    biases = tf.compat.v1.Variable(tf.compat.v1.zeros([1,out_size])+0.1,dtype=tf.compat.v1.float32,name='b')
    logit = tf.compat.v1.matmul(inputs,Weights) + biases
    if activation_function is None:
        output = logit
    else:
        output = activation_function(logit,)
    return output

#calculating accuracy
def compute_accuracy(xtest,ytest):
    global predicted
    ypred = sess.run(predicted,feed_dict={xs:xtest})
    correct_pred = tf.compat.v1.equal(tf.compat.v1.arg_max(ypred,1),tf.compat.v1.arg_max(ytest,1))
    accuracy = tf.compat.v1.reduce_mean(tf.compat.v1.cast(correct_pred,tf.compat.v1.float32))
    result = sess.run(accuracy,feed_dict={xs:xtest,ys:ytest})
    return result

import input_data
mnist = input_data.read_data_sets("MNIST/", one_hot=True)

#define placeholders for input to networks
xs = tf.compat.v1.placeholder(tf.compat.v1.float32,[None,784])  #28x28=784
ys = tf.compat.v1.placeholder(tf.compat.v1.float32,[None,10])   # 10 output classes

#just adding one layer i.e. directly the output layer
#adding one layer
predicted = add_layer(xs,784,10,tf.compat.v1.nn.softmax)

#y_hat_softmax = tf.nn.softmax(y_hat)  , yhat is logit
#total_loss = tf.reduce_mean(-tf.reduce_sum(y_true * tf.log(y_hat_softmax), [1]))
#or
#total_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(y_hat, y_true))

cross_entropy = tf.compat.v1.reduce_mean(-tf.compat.v1.reduce_sum(ys*tf.compat.v1.log(predicted),reduction_indices=[1]))
training = tf.compat.v1.train.GradientDescentOptimizer(0.5).minimize(cross_entropy)

saver = tf.compat.v1.train.Saver() 

sess = tf.compat.v1.Session()

#important step
sess.run(tf.compat.v1.initialize_all_variables())
savepath = saver.save(sess,'my_net/nnet_classification.ckpt')
print ("saved to path : "+savepath)
# Out:
# Extracting MNIST/train-images-idx3-ubyte.gz
# Extracting MNIST/train-labels-idx1-ubyte.gz
# Extracting MNIST/t10k-images-idx3-ubyte.gz
# Extracting MNIST/t10k-labels-idx1-ubyte.gz
# saved to path : my_net/nnet_classification.ckpt

# %%
#restore will need to redefine those weights
#no need to run init

import matplotlib
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt

def restore_layer_variable(in_size,out_size):
    #inputs from previous layer
    #in_size: size(number of neurons) of previous layer
    #out_size: size(number of neurons) of this layer
    #activation_function: used in this layer
    Weights = tf.compat.v1.Variable(tf.compat.v1.random_normal([in_size,out_size]),dtype=tf.compat.v1.float32,name='W')
    biases = tf.compat.v1.Variable(tf.compat.v1.zeros([1,out_size])+0.1,dtype=tf.compat.v1.float32,name='b')
    saver = tf.compat.v1.train.Saver()
    saver.restore(sess,'my_net/nnet_classification.ckpt')
    return {'weights':sess.run(Weights),'biases':sess.run(biases)}
    

with tf.compat.v1.Session() as sess:
    l1 = restore_layer_variable(784,10)
    print (l1)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#
# NotFoundError: Key W_2 not found in checkpoint
# 	 [[{{node save_4/RestoreV2}}]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1285         sess.run(self.saver_def.restore_op_name,
# -> 1286                  {self.saver_def.filename_tensor_name: save_path})
#    1287     except errors.NotFoundError as err:
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1369       message = error_interpolation.interpolate(message, self._graph)
# -> 1370       raise type(e)(node_def, op, message)
#    1371
#
# NotFoundError: Key W_2 not found in checkpoint
# 	 [[node save_4/RestoreV2 (defined at <ipython-input-17-b61644f9fdf9>:16) ]]
#
# Original stack trace for 'save_4/RestoreV2':
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/anaconda3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-b61644f9fdf9>", line 22, in <module>
#     l1 = restore_layer_variable(784,10)
#   File "<ipython-input-17-b61644f9fdf9>", line 16, in restore_layer_variable
#     saver = tf.compat.v1.train.Saver()
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 825, in __init__
#     self.build()
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 837, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 875, in _build
#     build_restore=build_restore)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 508, in _build_internal
#     restore_sequentially, reshape)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 328, in _AddRestoreOps
#     restore_sequentially)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 575, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1696, in restore_v2
#     name=name)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3296, in create_op
#     op_def=op_def)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1692, in __init__
#     self._traceback = tf_stack.extract_stack()
#
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1295       try:
# -> 1296         names_to_keys = object_graph_key_mapping(save_path)
#    1297       except errors.NotFoundError:
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py in object_graph_key_mapping(checkpoint_path)
#    1613   reader = pywrap_tensorflow.NewCheckpointReader(checkpoint_path)
# -> 1614   object_graph_string = reader.get_tensor(trackable.OBJECT_GRAPH_PROTO_KEY)
#    1615   object_graph_proto = (trackable_object_graph_pb2.TrackableObjectGraph())
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in get_tensor(self, tensor_str)
#     824
# --> 825       return CheckpointReader_GetTensor(self, compat.as_bytes(tensor_str))
#     826
#
# NotFoundError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-17-b61644f9fdf9> in <module>()
#      20
#      21 with tf.compat.v1.Session() as sess:
# ---> 22     l1 = restore_layer_variable(784,10)
#      23     print (l1)
#
# <ipython-input-17-b61644f9fdf9> in restore_layer_variable(in_size, out_size)
#      15     biases = tf.compat.v1.Variable(tf.compat.v1.zeros([1,out_size])+0.1,dtype=tf.compat.v1.float32,name='b')
#      16     saver = tf.compat.v1.train.Saver()
# ---> 17     saver.restore(sess,'my_net/nnet_classification.ckpt')
#      18     return {'weights':sess.run(Weights),'biases':sess.run(biases)}
#      19
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1300         # a helpful message (b/110263146)
#    1301         raise _wrap_restore_error_with_msg(
# -> 1302             err, "a Variable name or other graph key that is missing")
#    1303
#    1304       # This is an object-based checkpoint. We'll print a warning and then do
#
# NotFoundError: Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# Key W_2 not found in checkpoint
# 	 [[node save_4/RestoreV2 (defined at <ipython-input-17-b61644f9fdf9>:16) ]]
#
# Original stack trace for 'save_4/RestoreV2':
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/anaconda3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-b61644f9fdf9>", line 22, in <module>
#     l1 = restore_layer_variable(784,10)
#   File "<ipython-input-17-b61644f9fdf9>", line 16, in restore_layer_variable
#     saver = tf.compat.v1.train.Saver()
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 825, in __init__
#     self.build()
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 837, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 875, in _build
#     build_restore=build_restore)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 508, in _build_internal
#     restore_sequentially, reshape)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 328, in _AddRestoreOps
#     restore_sequentially)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 575, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1696, in restore_v2
#     name=name)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3296, in create_op
#     op_def=op_def)
#   File "/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1692, in __init__
#     self._traceback = tf_stack.extract_stack()

# %%
for i in range(20000):
    batch_xs,batch_ys = mnist.train.next_batch(1000)
    sess.run(training,feed_dict={xs:batch_xs,ys:batch_ys})
    if i%100==0:
        print (compute_accuracy(mnist.test.images,mnist.test.labels))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-84c32517af69> in <module>()
#       1 for i in range(20000):
#       2     batch_xs,batch_ys = mnist.train.next_batch(1000)
# ----> 3     sess.run(training,feed_dict={xs:batch_xs,ys:batch_ys})
#       4     if i%100==0:
#       5         print (compute_accuracy(mnist.test.images,mnist.test.labels))
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1094     # Check session.
#    1095     if self._closed:
# -> 1096       raise RuntimeError('Attempted to use a closed Session.')
#    1097     if self.graph.version == 0:
#    1098       raise RuntimeError('The Session graph is empty.  Add operations to the '
#
# RuntimeError: Attempted to use a closed Session.

# %%
abc=mnist.train

# %%
bcd,cde=abc.next_batch(500)

# %%
cde.shape
# Out:
# (500, 10)

# %%
a=tf.arg_max(cde,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-eafa321d985f> in <module>()
# ----> 1 a=tf.arg_max(cde,1)
#
# AttributeError: module 'tensorflow' has no attribute 'arg_max'

# %%
tf.Session().run(a)
# Out:
# array([3, 5, 0, 8, 5, 2, 8, 7, 8, 6, 7, 1, 8, 5, 9, 2, 3, 6, 9, 4, 9, 1, 3,
#        8, 5, 7, 6, 5, 7, 5, 1, 1, 4, 8, 8, 9, 4, 1, 0, 3, 2, 6, 9, 3, 8, 3,
#        4, 2, 6, 2, 7, 6, 4, 6, 1, 5, 4, 5, 1, 3, 4, 3, 6, 8, 9, 1, 7, 6, 1,
#        5, 1, 6, 6, 8, 6, 1, 3, 9, 6, 7, 8, 6, 8, 8, 3, 3, 1, 7, 9, 9, 7, 0,
#        3, 0, 3, 3, 4, 7, 4, 9, 7, 3, 6, 0, 8, 2, 8, 0, 4, 1, 5, 0, 3, 1, 0,
#        0, 7, 1, 8, 0, 8, 4, 8, 7, 2, 9, 2, 2, 2, 0, 0, 6, 3, 2, 9, 6, 5, 2,
#        6, 2, 1, 9, 2, 9, 5, 0, 5, 1, 0, 2, 7, 3, 4, 4, 1, 5, 4, 6, 3, 8, 5,
#        9, 3, 0, 5, 1, 7, 3, 9, 4, 6, 5, 4, 6, 4, 7, 0, 8, 1, 9, 5, 0, 1, 1,
#        0, 2, 7, 3, 7, 4, 6, 5, 6, 6, 9, 7, 7, 8, 1, 9, 0, 1, 1, 8, 0, 6, 3,
#        7, 0, 1, 3, 3, 5, 7, 4, 7, 4, 9, 1, 3, 6, 6, 7, 0, 4, 2, 6, 6, 8, 4,
#        0, 8, 6, 4, 9, 5, 1, 0, 0, 3, 7, 9, 6, 2, 8, 1, 8, 1, 1, 5, 3, 9, 7,
#        4, 3, 2, 7, 0, 0, 4, 8, 4, 3, 0, 2, 9, 3, 6, 0, 9, 7, 2, 5, 2, 8, 1,
#        5, 7, 4, 9, 2, 5, 5, 1, 3, 1, 5, 9, 8, 6, 9, 0, 8, 1, 4, 8, 6, 4, 4,
#        6, 6, 8, 0, 8, 4, 2, 8, 6, 8, 3, 4, 2, 4, 9, 8, 2, 8, 4, 7, 0, 9, 9,
#        1, 0, 7, 3, 3, 3, 6, 5, 5, 8, 0, 4, 1, 7, 5, 6, 9, 2, 5, 2, 9, 7, 3,
#        7, 2, 0, 5, 5, 9, 1, 5, 5, 6, 3, 3, 0, 3, 1, 2, 2, 7, 3, 1, 4, 7, 5,
#        5, 6, 1, 7, 9, 8, 6, 0, 6, 1, 7, 4, 1, 7, 7, 0, 5, 1, 9, 4, 5, 7, 4,
#        8, 3, 9, 3, 6, 8, 8, 3, 2, 1, 4, 7, 6, 3, 8, 3, 6, 7, 6, 2, 7, 3, 1,
#        7, 7, 8, 0, 9, 2, 3, 2, 9, 0, 8, 1, 1, 6, 0, 5, 6, 1, 7, 2, 9, 0, 5,
#        2, 8, 3, 8, 4, 8, 8, 2, 3, 1, 7, 2, 4, 9, 1, 8, 7, 6, 4, 7, 8, 0, 3,
#        0, 9, 8, 6, 9, 7, 3, 0, 0, 9, 0, 6, 0, 0, 2, 6, 8, 1, 5, 0, 5, 5, 6,
#        5, 5, 1, 7, 0, 5, 1, 4, 0, 2, 9, 8, 4, 4, 5, 1, 9])

# %%
tf.Session().run(tf.cast(a,tf.float32))
# Out:
# array([ 3.,  5.,  0.,  8.,  5.,  2.,  8.,  7.,  8.,  6.,  7.,  1.,  8.,
#         5.,  9.,  2.,  3.,  6.,  9.,  4.,  9.,  1.,  3.,  8.,  5.,  7.,
#         6.,  5.,  7.,  5.,  1.,  1.,  4.,  8.,  8.,  9.,  4.,  1.,  0.,
#         3.,  2.,  6.,  9.,  3.,  8.,  3.,  4.,  2.,  6.,  2.,  7.,  6.,
#         4.,  6.,  1.,  5.,  4.,  5.,  1.,  3.,  4.,  3.,  6.,  8.,  9.,
#         1.,  7.,  6.,  1.,  5.,  1.,  6.,  6.,  8.,  6.,  1.,  3.,  9.,
#         6.,  7.,  8.,  6.,  8.,  8.,  3.,  3.,  1.,  7.,  9.,  9.,  7.,
#         0.,  3.,  0.,  3.,  3.,  4.,  7.,  4.,  9.,  7.,  3.,  6.,  0.,
#         8.,  2.,  8.,  0.,  4.,  1.,  5.,  0.,  3.,  1.,  0.,  0.,  7.,
#         1.,  8.,  0.,  8.,  4.,  8.,  7.,  2.,  9.,  2.,  2.,  2.,  0.,
#         0.,  6.,  3.,  2.,  9.,  6.,  5.,  2.,  6.,  2.,  1.,  9.,  2.,
#         9.,  5.,  0.,  5.,  1.,  0.,  2.,  7.,  3.,  4.,  4.,  1.,  5.,
#         4.,  6.,  3.,  8.,  5.,  9.,  3.,  0.,  5.,  1.,  7.,  3.,  9.,
#         4.,  6.,  5.,  4.,  6.,  4.,  7.,  0.,  8.,  1.,  9.,  5.,  0.,
#         1.,  1.,  0.,  2.,  7.,  3.,  7.,  4.,  6.,  5.,  6.,  6.,  9.,
#         7.,  7.,  8.,  1.,  9.,  0.,  1.,  1.,  8.,  0.,  6.,  3.,  7.,
#         0.,  1.,  3.,  3.,  5.,  7.,  4.,  7.,  4.,  9.,  1.,  3.,  6.,
#         6.,  7.,  0.,  4.,  2.,  6.,  6.,  8.,  4.,  0.,  8.,  6.,  4.,
#         9.,  5.,  1.,  0.,  0.,  3.,  7.,  9.,  6.,  2.,  8.,  1.,  8.,
#         1.,  1.,  5.,  3.,  9.,  7.,  4.,  3.,  2.,  7.,  0.,  0.,  4.,
#         8.,  4.,  3.,  0.,  2.,  9.,  3.,  6.,  0.,  9.,  7.,  2.,  5.,
#         2.,  8.,  1.,  5.,  7.,  4.,  9.,  2.,  5.,  5.,  1.,  3.,  1.,
#         5.,  9.,  8.,  6.,  9.,  0.,  8.,  1.,  4.,  8.,  6.,  4.,  4.,
#         6.,  6.,  8.,  0.,  8.,  4.,  2.,  8.,  6.,  8.,  3.,  4.,  2.,
#         4.,  9.,  8.,  2.,  8.,  4.,  7.,  0.,  9.,  9.,  1.,  0.,  7.,
#         3.,  3.,  3.,  6.,  5.,  5.,  8.,  0.,  4.,  1.,  7.,  5.,  6.,
#         9.,  2.,  5.,  2.,  9.,  7.,  3.,  7.,  2.,  0.,  5.,  5.,  9.,
#         1.,  5.,  5.,  6.,  3.,  3.,  0.,  3.,  1.,  2.,  2.,  7.,  3.,
#         1.,  4.,  7.,  5.,  5.,  6.,  1.,  7.,  9.,  8.,  6.,  0.,  6.,
#         1.,  7.,  4.,  1.,  7.,  7.,  0.,  5.,  1.,  9.,  4.,  5.,  7.,
#         4.,  8.,  3.,  9.,  3.,  6.,  8.,  8.,  3.,  2.,  1.,  4.,  7.,
#         6.,  3.,  8.,  3.,  6.,  7.,  6.,  2.,  7.,  3.,  1.,  7.,  7.,
#         8.,  0.,  9.,  2.,  3.,  2.,  9.,  0.,  8.,  1.,  1.,  6.,  0.,
#         5.,  6.,  1.,  7.,  2.,  9.,  0.,  5.,  2.,  8.,  3.,  8.,  4.,
#         8.,  8.,  2.,  3.,  1.,  7.,  2.,  4.,  9.,  1.,  8.,  7.,  6.,
#         4.,  7.,  8.,  0.,  3.,  0.,  9.,  8.,  6.,  9.,  7.,  3.,  0.,
#         0.,  9.,  0.,  6.,  0.,  0.,  2.,  6.,  8.,  1.,  5.,  0.,  5.,
#         5.,  6.,  5.,  5.,  1.,  7.,  0.,  5.,  1.,  4.,  0.,  2.,  9.,
#         8.,  4.,  4.,  5.,  1.,  9.], dtype=float32)
